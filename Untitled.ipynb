# %%
did_not_work = open("txt.txt")
reqs = open("environment.yaml")

# %%
dnw = []
for line in did_not_work:
    dnw.append(line[:-1])
dnw
# Out:
# ['  - brunsli==0.1=h23ab428_0',
#  '  - brotli-bin==1.0.9=hca72f7f_7',
#  '  - pprintpp==0.4.0=py37hf985489_4',
#  '  - libssh2==1.10.0=h0a4fc7d_0',
#  '  - imagecodecs==2021.8.26=py37h0f85e6e_1',
#  '  - jpeg==9e=hca72f7f_0',
#  '  - libwebp-base==1.2.4=hca72f7f_0',
#  '  - libbrotlicommon==1.0.9=hca72f7f_7',
#  '  - ca-certificates==2022.10.11=hecd8cb5_0',
#  '  - charls==2.2.0=h23ab428_0',
#  '  - blosc==1.21.0=h8346a28_1',
#  '  - bottleneck==1.3.5=py37h67323c0_0',
#  '  - jinja2==3.1.2=py37hecd8cb5_0',
#  '  - pip==22.2.2=py37hecd8cb5_0',
#  '  - pysocks==1.7.1=py37hecd8cb5_0',
#  '  - llvm-openmp==14.0.6=h0dcd299_0',
#  '  - libdeflate==1.8=h9ed2024_5',
#  '  - freetype==2.12.1=hd8bbffd_0',
#  '  - gunicorn==20.1.0=py37hecd8cb5_0',
#  '  - libtiff==4.4.0=h2ef1027_1',
#  '  - mako==1.2.3=py37hecd8cb5_0',
#  '  - cytoolz==0.12.0=py37hca72f7f_0',
#  '  - libprotobuf==3.20.1=h8346a28_0',
#  '  - h5py==3.7.0=py37h4a1dd59_0',
#  '  - mkl_fft==1.3.1=py37h4ab4a9b_0',
# ...

# %%
filte = False
for line in reqs:
    filte = False
    print(line)
    for element in dnw:
        if line.startswith(element):
            filte = True
    if filte:
        print(element)
    else:
        with open("env.txt", "a") as file:
            print(line)
            file.write(line)
            file.close
# Out:
# channels:
#
# channels:
#
#   - pytorch
#
#   - pytorch
#
#   - conda-forge
#
#   - conda-forge
#
#   - defaults
#
#   - defaults
#
# dependencies:
#
# dependencies:
#
#   - _tflow_select=2.3.0=mkl
#
#   - _tflow_select=2.3.0=mkl
#
#   - absl-py=1.3.0=pyhd8ed1ab_0
#
#   - absl-py=1.3.0=pyhd8ed1ab_0
#
#   - alembic=1.3.1=py_0
#
#   - alembic=1.3.1=py_0
#
#   - appdirs=1.4.4=pyhd3eb1b0_0
#
#   - appdirs=1.4.4=pyhd3eb1b0_0
#
#   - asn1crypto=1.5.1=py37hecd8cb5_0
#
#   - asn1crypto=1.5.1=py37hecd8cb5_0
#
#   - astor=0.8.1=py37hecd8cb5_0
#
#   - astor=0.8.1=py37hecd8cb5_0
#
#   - azure-core=1.14.0=pyhd3eb1b0_0
#
#   - azure-core=1.14.0=pyhd3eb1b0_0
#
#   - azure-storage-blob=12.9.0=pyhd3eb1b0_0
#
#   - azure-storage-blob=12.9.0=pyhd3eb1b0_0
#
#   - blas=1.0=mkl
#
#   - blas=1.0=mkl
#
#   - blinker=1.4=py37hecd8cb5_0
#
#   - blinker=1.4=py37hecd8cb5_0
#
#   - blosc=1.21.0=h8346a28_1
#
#   - blosc=1.21.0=h8346a28_1
#
#   - bottleneck=1.3.5=py37h67323c0_0
#
# ...
